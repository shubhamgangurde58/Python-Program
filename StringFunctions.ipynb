# %%
# String Function / Methods 
# > all string function return new values becouse string are immutable 

# 1. capitalize()
# . capitalizes(convert lower case to upper case ) the first character of the string

# %%
s1 = "shubham gangurde"
s1.capitalize()
# Out:
# 'Shubham gangurde'

# %%
s1 = s1.capitalize()

# %%
s1
# Out:
# 'Shubham gangurde'

# %%
# 2. Upper case 
# . convert string from lower case to upper case 
# . e.g string.upper()

# %%
s1.upper()
# Out:
# 'SHUBHAM GANGURDE'

# %%
s1
# Out:
# 'Shubham gangurde'

# %%
s1 = s1.upper()
s1
# Out:
# 'SHUBHAM GANGURDE'

# %%
s1
# Out:
# 'SHUBHAM GANGURDE'

# %%
s1
# Out:
# 'SHUBHAM GANGURDE'

# %%
pan = "abcd1234z"
pan.upper()
# Out:
# 'ABCD1234Z'

# %%
# 3 . Lower case 
# . converts upper to lower case 
# . e.g string.lower()

# %%
s1
# Out:
# 'SHUBHAM GANGURDE'

# %%
s1.lower()
# Out:
# 'shubham gangurde'

# %%
# 4. Title case 
# . capitalizes first letter of each word in the string 
# . string.title()

# %%
s2 = "united states of america"
s2.title()
# Out:
# 'United States Of America'

# %%
# 5. Casefold
# . stronger version of lower() function 
# . converts some special symbols to lower 
# . e.g string.casefold()


word = "Scheiße"
word.lower()
# Out:
# 'scheiße'

# %%
word.casefold()
# Out:
# 'scheisse'

# %%
# 6. Istrip()
# . removes the leading(on left side) white space from the string 

string = '         shubham'
string
# Out:
# '         shubham'

# %%
string.lstrip()
# Out:
# 'shubham'

# %%
# 7. rstrip()
# . removes the trailing( on right side) white spaces 
# e.g string.rstrip()

string = 'python            '
string
# Out:
# 'python            '

# %%
string.rstrip()
# Out:
# 'python'

# %%
# 8 strip()
# . removes the leading as well as trailing white spaces 

string = '    Data science        '
string
# Out:
# '    Data science        '

# %%
string.strip()
# Out:
# 'Data science'

# %%
# use case --> space on documents
# e.g 
'      Government of India       '
# Out:
# '      Government of India       '

# %%
# 9 swapcase()
# . inverts the case of all char in the string 

string = 'mETS institute of management Nashik'
string.swapcase()
# Out:
# 'Mets INSTITUTE OF MANAGEMENT nASHIK'

# %%
# 10 . replace
# . used for replacing a part of string(char or word) by another char or word 
# . syntax  : string.replace('old_str','new_str',count = 1)

s1 = 'Data %^& Science'
s1.replace('%^&', '***')
# Out:
# 'Data *** Science'

# %%
s1.replace('%^&','')
# Out:
# 'Data  Science'

# %%
string
# Out:
# 'mETS institute of management Nashik'

# %%
string.replace('e','-')
# Out:
# 'mETS institut- of manag-m-nt Nashik'

# %%
string.replace('e','-',1)
# Out:
# 'mETS institut- of management Nashik'

# %%
string.replace('e','-',2)
# Out:
# 'mETS institut- of manag-ment Nashik'

# %%
# remove all vawels from the string
s1 = 'London bridge is falling down'
s1.replace('o','')
# Out:
# 'Lndn bridge is falling dwn'

# %%
s1
# Out:
# 'London bridge is falling down'

# %%
s1 = s1.replace('a','')
print(s1)
s1 = s1.replace('e','')
print(s1)
s1 = s1.replace('i','')
print(s1)
s1 = s1.replace('o','')
print(s1)
s1 = s1.replace('u','')
print(s1)
# Out:
# London bridge is flling down
# London bridg is flling down
# London brdg s fllng down
# Lndn brdg s fllng dwn
# Lndn brdg s fllng dwn

# %%
s1 = 'London bridge is falling down'

# %%
s1
# Out:
# 'London bridge is falling down'

# %%
# method 2
s1 = s1.replace('a', '').replace('e','').replace('i','').replace('o','').replace('u','')
s1
# Out:
# 'Lndn brdg s fllng dwn'

# %%
# 11. split()
# . converts a string to list
# . we can split the string by a particular char

# syntax : string.split(sep=None, maxsplit = -1)
# . default separator is space

s1 = 'London bridge is falling down '
s1
# Out:
# 'London bridge is falling down '

# %%
s1.split()
# Out:
# ['London', 'bridge', 'is', 'falling', 'down']

# %%
s1.split('i')
# Out:
# ['London br', 'dge ', 's fall', 'ng down ']

# %%
list1 = s1.split('i')
list1
# Out:
# ['London br', 'dge ', 's fall', 'ng down ']

# %%
type(list1)
# Out:
# list

# %%
# 12 . count()
# . return the number of non - overlapping occurences of a sub string 
# . syntax : string.count('sub_str',start_index, end_index)

s1
# Out:
# 'London bridge is falling down '

# %%
s1.count('i')
# Out:
# 3

# %%
s1.count('i',7,16)
# Out:
# 2

# %%
# 13 len()
# . returns the length of string
# . syntax: len(string)

string
# Out:
# 'mETS institute of management Nashik'

# %%
len(string)
# Out:
# 35

# %%
# 14 . index
# . returns the index of a particular char 
# . in case of multiple occurences returns the index of first occurence
# . gives error if char is not found
# . syntax string.index('sub_str', start_index, end_index)

s1
# Out:
# 'London bridge is falling down '

# %%
s1.index('b')
# Out:
# 7

# %%
s1.index('i')
# Out:
# 9

# %%
s1.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 s1.index('z')
#
# ValueError: substring not found

# %%
s1.index('down')
# Out:
# 25

# %%
s1.index('i',12,15)
# Out:
# 14

# %%
# 15. find()
# . similar to index just that return -1 (instead of error) if char / sub string is not found
# . syntax : string.find('sub_str', start_index, end_index)

s1.find('i')
s1.strip()
# Out:
# 'London bridge is falling down'

# %%
# 16. endswith()
# . checks is the  string ends with a particular sub string/ char
# . returns a boolean value(True or False)
# . use case --> to find the files with particular extension(e.g pdf, jpg,xls)
# . syntax : string.endswith('suffix',start_index,end_index)

s1
# Out:
# 'London bridge is falling down '

# %%
s1.endswith('down ')
# Out:
# True

# %%
s1.endswith('own ')
# Out:
# True

# %%
s1.endswith('on')
# Out:
# False

# %%
file_path = r'E:/Desktop'
file_path.endswith('top')
# Out:
# True

# %%
import os
file_list = os.listdir(C:\Users\vidhan\Pictures\StudentManagementSystemProjectImages\WordDocument\GUIDemo)
file_list
# Out:
#   Cell In[56], line 2
#     file_list = os.listdir(C:\Users\vidhan\Pictures\StudentManagementSystemProjectImages\WordDocument\GUIDemo)
#                             ^
# SyntaxError: invalid syntax

# %%
for file in file_list:
    if file.endswith('.pdf'):
        print("PDF file is Present")
    else:
        print("PDF file is not Present")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 for file in file_list:
#       2     if file.endswith('.pdf'):
#       3         print("PDF file is Present")
#
# NameError: name 'file_list' is not defined

# %%
# 17. startswith()
# . checks if the string starts with a particular sub string/ char/ prefix
# . returns a boolan values(True or false)
# . syntax : string.startswith('prefix',start_index, end_index)

s1
# Out:
# 'London bridge is falling down '

# %%
s1.startswith('Lon')
# Out:
# True

# %%
s1.startswith('lon')
# Out:
# False

# %%
# 18 . isalnum()
#. checks whether string is aplhanumeric or not(alphabets or number)
# . returns True or False

s1
# Out:
# 'London bridge is falling down '

# %%
s1.isalnum()
# Out:
# False
