# %%
# String Demo 
# > Collection of characters surrounded by '' or   "" 
# > multipline string is surrounded by ''' ''' or """ """
# > immutable(cannot be modified)
# > indexing and slicing 
# > string is iterable

# %%
str_1 = 'python'
print(str_1 , type(str_1))
# Out:
# python <class 'str'>

# %%
str_2 = 'life's secrets '
# Out:
#   Cell In[4], line 1
#     str_2 = 'life's secrets '
#                             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str_2 = "life's secrets"
print(str_2)
# Out:
# life's secrets

# %%
# INDEXING AND SLICING
# > every char in string has a number called as index
# > syntax --> string[start_index: end_index: step]
# > start_index is included and end_index is excluded

# %%
str_2[0]
# Out:
# 'l'

# %%
str_2[7]
# Out:
# 's'

# %%
str_2[2:7]
# Out:
# "fe's "

# %%
str_2[0:4]
# Out:
# 'life'

# %%
str_2[:4]
# Out:
# 'life'

# %%
str_2[:]
# Out:
# "life's secrets"

# %%
str_2[::]
# Out:
# "life's secrets"

# %%
str_2[::2] # even char
# Out:
# "lf' ert"

# %%
str_2[1::2] # odd char
# Out:
# 'iessces'

# %%
str_2[::3]
# Out:
# 'le ct'

# %%
# print only odd chr of a string 
string = "Java Programming"
string[1::2]
# Out:
# 'aaPormig'

# %%
# print first 5 char in string 
string[:5]
# Out:
# 'Java '

# %%
# skip first 5 char in string
string[5:]
# Out:
# 'Programming'

# %%
# Negative Indexing
print(string)
string[-1]
# Out:
# Java Programming
# 'g'

# %%
string[-16]
# Out:
# 'J'

# %%
string[:]
# Out:
# 'Java Programming'

# %%
str_1 = """Scaler Data Science is an online learing program designed for work"""

# %%
str_1
# Out:
# 'Scaler Data Science is an online learing program designed for working'

# %%
# print last 5 char of string 
string[-5:]
# Out:
# 'mming'

# %%
# skip last 5 char of string 
string[:-5]
# Out:
# 'Java Progra'

# %%
# print last 15 char in str_1
str_1[-15:]
# Out:
# 'ned for working'

# %%
# reverse the string  "gnimmargorp avaj"
string[::-1]
# Out:
# 'gnimmargorP avaJ'

# %%
# write a program to check the string is palindrame
str1 = input("Enter the string : ")
if str1 == str1[::-1]:
    print("String is palindrame")
else:
    print("String is not palindrame")
# Out:
# Enter the string :  nayan
# String is palindrame

# %%
string
# Out:
# 'Java Programming'

# %%
string[5:1:-1]
# Out:
# 'P av'

# %%
string[4::-1]
# Out:
# ' avaJ'

# %%
string[:-5:-1]
# Out:
# 'gnim'

# %%
string[0]
# Out:
# 'J'

# %%
string[0] = 'p'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 string[0] = 'p'
#
# TypeError: 'str' object does not support item assignment

# %%
for i , ch in enumerate(string):
    print("index : ",i," char : ",ch)
# Out:
# index :  0  char :  J
# index :  1  char :  a
# index :  2  char :  v
# index :  3  char :  a
# index :  4  char :
# index :  5  char :  P
# index :  6  char :  r
# index :  7  char :  o
# index :  8  char :  g
# index :  9  char :  r
# index :  10  char :  a
# index :  11  char :  m
# index :  12  char :  m
# index :  13  char :  i
# index :  14  char :  n
# index :  15  char :  g

# %%
for i , ch in enumerate(string):
    print("index : {} char : {} ".format(i,ch))
# Out:
# index : 0 char : J
# index : 1 char : a
# index : 2 char : v
# index : 3 char : a
# index : 4 char :
# index : 5 char : P
# index : 6 char : r
# index : 7 char : o
# index : 8 char : g
# index : 9 char : r
# index : 10 char : a
# index : 11 char : m
# index : 12 char : m
# index : 13 char : i
# index : 14 char : n
# index : 15 char : g

# %%
len(string)
# Out:
# 16

# %%
for i , ch in enumerate(string):
    print(f"index : {i} char : {ch}")
# Out:
# index : 0 char : J
# index : 1 char : a
# index : 2 char : v
# index : 3 char : a
# index : 4 char :
# index : 5 char : P
# index : 6 char : r
# index : 7 char : o
# index : 8 char : g
# index : 9 char : r
# index : 10 char : a
# index : 11 char : m
# index : 12 char : m
# index : 13 char : i
# index : 14 char : n
# index : 15 char : g

# %%
# check if a char is present in a string
# check if 'L' is present in 'Learning'

if "m" in string:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
s = input("Enter the String : ")
c = input("Enter the char t obe searched : ")

if c in s :
    print("YES")
else:
    print("NO")
# Out:
# Enter the String :  shubham
# Enter the char t obe searched :  b
# YES

# %%
# WAP 
string = "Shubham"
print(string[1:-1])
# Out:
# hubha

# %%
string[0]
# Out:
# 'S'

# %%
string[1:len(string)-1]
# Out:
# 'hubha'

# %%
string[-1]
# Out:
# 'm'

# %%
new_str = string[-1]+string[1:len(string)-1]+string[0]
print(new_str)
# Out:
# mhubhaS
